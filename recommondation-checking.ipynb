# %%
import numpy as np # linear algebra
import pandas as pd # data processing

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
medicine = pd.read_csv("C:\\Users\\LENOVO\\Desktop\\SIH 2023\\ayurtech\\ML model\\new.csv")

# %%
medicine.to_pickle("C:\\Users\LENOVO\\Desktop\\SIH 2023\\ayurtech\\ML model\\new.df.pkl")
medicines = pd.read_pickle("C:\\Users\\LENOVO\\Desktop\\SIH 2023\\ayurtech\\ML model\\new.df.pkl")

# %%
medicines.head()
# Out:
#                      Name_of_Medicine  \
# 0                       ABHAYARISHTAM
# 1                       AMRITARISHTAM
# 2                    ARAGWADHARISHTAM
# 3                     ARAVINDASAVAM
# 4  Arjunarishta / ( Parthadyarishta )
#
#                                         Composition   \
# 0  Guda,Abhaya,Dhatri,Kapitha,Visala,Lodhra,Maric...
# 1  Guda, Amrita, Kashmari, Vilwa, Patala, Syonaka...
# 2  Kshaudra, Aragwadha mula, Aragwadha patra, Ara...
# 3  Sarkara, Makshika, Aravinda, Usira, Kashmari, ...
# 4  Guda, Parthatwak, Mridwika, Madhukapushpa, Dha...
#
#                       Reference_Text  \
# 0  Ashtangahridayam, Chikitsasthanam
# 1     Bhaishajyaratnavali Adhyayam 5
# 2                   Ashtangahridayam
# 3    Bhaishajyaratnavali Adhyayam 17
# 4       Ayurvedic Formulary of India
#
#                                     Main_Indications  \
# 0  Hemorrhoids, Arsha, Piles, Agnimandya, Udararo...
# 1  Sarva, Jwara, Fever, Bukhar, Taap, Jeerna, Chr...
# ...

# %%
medicines.shape
# Out:
# (438, 7)

# %%
medicines.isnull().sum()
# Out:
# Name_of_Medicine                   0
# Composition                        1
# Reference_Text                     0
# Main_Indications                   0
# Dose_and_Mode_of_Administration    0
# Precaution/Contraindication        0
# Medical_Preparation                0
# dtype: int64

# %%
medicines.dropna(inplace=True)

# %%
medicines.duplicated().sum()
# Out:
# 0

# %%
medicines['Main_Indications']
# Out:
# 0      Hemorrhoids, Arsha, Piles, Agnimandya, Udararo...
# 1      Sarva, Jwara, Fever, Bukhar, Taap, Jeerna, Chr...
# 2      Kandu, Twak Vikar, Vibandha,Mild laxative and ...
# 3               Balaroga, Balakshaya, Agnimandya, Aruchi
# 4      Hridroga, Hriddrav, Hrid - daurbalya, Moha, Mu...
#                              ...
# 433    Improves vision, gives coolness and comfort to...
# 434                Dermatitis and folliculitis of scalp.
# 435                             Chronic ulcers, bedsores
# 436                          Scabies, itchy skin rashes.
# 437                       Growth and firmness of breast.
# Name: Main_Indications, Length: 437, dtype: object

# %%
medicines['Main_Indications'].apply(lambda x:x.split())
# Out:
# 0      [Hemorrhoids,, Arsha,, Piles,, Agnimandya,, Ud...
# 1      [Sarva,, Jwara,, Fever,, Bukhar,, Taap,, Jeern...
# 2      [Kandu,, Twak, Vikar,, Vibandha,Mild, laxative...
# 3          [Balaroga,, Balakshaya,, Agnimandya,, Aruchi]
# 4      [Hridroga,, Hriddrav,, Hrid, -, daurbalya,, Mo...
#                              ...
# 433    [Improves, vision,, gives, coolness, and, comf...
# 434          [Dermatitis, and, folliculitis, of, scalp.]
# 435                         [Chronic, ulcers,, bedsores]
# 436                     [Scabies,, itchy, skin, rashes.]
# 437                 [Growth, and, firmness, of, breast.]
# Name: Main_Indications, Length: 437, dtype: object

# %%
medicines['Dose_and_Mode_of_Administration'] = medicines['Dose_and_Mode_of_Administration'].apply(lambda x:x.split())
medicines['Main_Indications'] = medicines['Main_Indications'].apply(lambda x:x.split())

# %%
medicines['Main_Indications'] = medicines['Main_Indications'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['Main_Indications'] = medicines['Main_Indications'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['tags'] = medicines['Main_Indications'] + medicines['Dose_and_Mode_of_Administration']

# %%
new_df = medicines

# %%
new_df
# Out:
#                        Name_of_Medicine  \
# 0                         ABHAYARISHTAM
# 1                         AMRITARISHTAM
# 2                      ARAGWADHARISHTAM
# 3                       ARAVINDASAVAM
# 4    Arjunarishta / ( Parthadyarishta )
# ..                                  ...
# 433             VILWAMPACHOTYADI TAILAM
# 434                 VILWAPATRADI TAILAM
# 435                   VRANAROPANATAILAM
# 436          YASHTIMADHUKADI KERATAILAM
# 437                     YUVATYADITAILAM
#
#                                           Composition   \
# 0    Guda,Abhaya,Dhatri,Kapitha,Visala,Lodhra,Maric...
# 1    Guda, Amrita, Kashmari, Vilwa, Patala, Syonaka...
# 2    Kshaudra, Aragwadha mula, Aragwadha patra, Ara...
# 3    Sarkara, Makshika, Aravinda, Usira, Kashmari, ...
# 4    Guda, Parthatwak, Mridwika, Madhukapushpa, Dha...
# ..                                                 ...
# 433  Tailam, Vivam, Lodhra, Bhringa, Amrita, Durva,...
# ...

# %%
new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# 0      Hemorrhoids, Arsha, Piles, Agnimandya, Udararo...
# 1      Sarva, Jwara, Fever, Bukhar, Taap, Jeerna, Chr...
# 2      Kandu, Twak Vikar, Vibandha,Mild laxative and ...
# 3      Balaroga, Balakshaya, Agnimandya, Aruchi 12 to...
# 4      Hridroga, Hriddrav, Hrid - daurbalya, Moha, Mu...
#                              ...
# 433    Improves vision, gives coolness and comfort to...
# 434    Dermatitis and folliculitis of scalp. Apply bo...
# 435    Chronic ulcers, bedsores Apply body oil libera...
# 436    Scabies, itchy skin rashes. Apply body oil lib...
# 437    Growth and firmness of breast. Apply body oil ...
# Name: tags, Length: 437, dtype: object

# %%
new_df
# Out:
#                        Name_of_Medicine  \
# 0                         ABHAYARISHTAM
# 1                         AMRITARISHTAM
# 2                      ARAGWADHARISHTAM
# 3                       ARAVINDASAVAM
# 4    Arjunarishta / ( Parthadyarishta )
# ..                                  ...
# 433             VILWAMPACHOTYADI TAILAM
# 434                 VILWAPATRADI TAILAM
# 435                   VRANAROPANATAILAM
# 436          YASHTIMADHUKADI KERATAILAM
# 437                     YUVATYADITAILAM
#
#                                           Composition   \
# 0    Guda,Abhaya,Dhatri,Kapitha,Visala,Lodhra,Maric...
# 1    Guda, Amrita, Kashmari, Vilwa, Patala, Syonaka...
# 2    Kshaudra, Aragwadha mula, Aragwadha patra, Ara...
# 3    Sarkara, Makshika, Aravinda, Usira, Kashmari, ...
# 4    Guda, Parthatwak, Mridwika, Madhukapushpa, Dha...
# ..                                                 ...
# 433  Tailam, Vivam, Lodhra, Bhringa, Amrita, Durva,...
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df
# Out:
#                        Name_of_Medicine  \
# 0                         ABHAYARISHTAM
# 1                         AMRITARISHTAM
# 2                      ARAGWADHARISHTAM
# 3                       ARAVINDASAVAM
# 4    Arjunarishta / ( Parthadyarishta )
# ..                                  ...
# 433             VILWAMPACHOTYADI TAILAM
# 434                 VILWAPATRADI TAILAM
# 435                   VRANAROPANATAILAM
# 436          YASHTIMADHUKADI KERATAILAM
# 437                     YUVATYADITAILAM
#
#                                           Composition   \
# 0    Guda,Abhaya,Dhatri,Kapitha,Visala,Lodhra,Maric...
# 1    Guda, Amrita, Kashmari, Vilwa, Patala, Syonaka...
# 2    Kshaudra, Aragwadha mula, Aragwadha patra, Ara...
# 3    Sarkara, Makshika, Aravinda, Usira, Kashmari, ...
# 4    Guda, Parthatwak, Mridwika, Madhukapushpa, Dha...
# ..                                                 ...
# 433  Tailam, Vivam, Lodhra, Bhringa, Amrita, Durva,...
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df
# Out:
#                        Name_of_Medicine  \
# 0                         ABHAYARISHTAM
# 1                         AMRITARISHTAM
# 2                      ARAGWADHARISHTAM
# 3                       ARAVINDASAVAM
# 4    Arjunarishta / ( Parthadyarishta )
# ..                                  ...
# 433             VILWAMPACHOTYADI TAILAM
# 434                 VILWAPATRADI TAILAM
# 435                   VRANAROPANATAILAM
# 436          YASHTIMADHUKADI KERATAILAM
# 437                     YUVATYADITAILAM
#
#                                           Composition   \
# 0    Guda,Abhaya,Dhatri,Kapitha,Visala,Lodhra,Maric...
# 1    Guda, Amrita, Kashmari, Vilwa, Patala, Syonaka...
# 2    Kshaudra, Aragwadha mula, Aragwadha patra, Ara...
# 3    Sarkara, Makshika, Aravinda, Usira, Kashmari, ...
# 4    Guda, Parthatwak, Mridwika, Madhukapushpa, Dha...
# ..                                                 ...
# 433  Tailam, Vivam, Lodhra, Bhringa, Amrita, Durva,...
# ...

# %%
# %pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -treamlit (c:\users\anjali\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\anjali\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\anjali\appdata\local\programs\python\python310\lib\site-packages)

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
# !pip install -U scikit-learn scipy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words='english',max_features=5000)

# %%
def stem(text):
  y = []

  for i in text.split():
    y.append(ps.stem(i))

  return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)

# %%
cv.fit_transform(new_df['tags']).toarray().shape
# Out:
# (437, 852)

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
#cv.get_feature_names()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.37310125, 0.43643578, ..., 0.        , 0.        ,
#         0.        ],
#        [0.37310125, 1.        , 0.37219368, ..., 0.03370999, 0.        ,
#         0.        ],
#        [0.43643578, 0.37219368, 1.        , ..., 0.06900656, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.03370999, 0.06900656, ..., 1.        , 0.91364988,
#         0.925     ],
#        [0.        , 0.        , 0.        , ..., 0.91364988, 1.        ,
#         0.91364988],
#        [0.        , 0.        , 0.        , ..., 0.925     , 0.91364988,
#         1.        ]])

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[1]
# Out:
# array([0.37310125, 1.        , 0.37219368, 0.44997704, 0.41391868,
#        0.44997704, 0.43082022, 0.44997704, 0.38533732, 0.43082022,
#        0.37310125, 0.44997704, 0.39886202, 0.44997704, 0.44997704,
#        0.43082022, 0.44997704, 0.43082022, 0.41391868, 0.43082022,
#        0.44997704, 0.44997704, 0.32141217, 0.30772873, 0.34188173,
#        0.34238119, 0.44997704, 0.35533453, 0.06428243, 0.05025189,
#        0.05504819, 0.05504819, 0.05913124, 0.05504819, 0.10050378,
#        0.04767313, 0.10050378, 0.05330018, 0.11396058, 0.06154575,
#        0.05913124, 0.05170877, 0.05698029, 0.09090909, 0.2665009 ,
#        0.05913124, 0.05698029, 0.05698029, 0.04767313, 0.06154575,
#        0.10341754, 0.11009638, 0.05504819, 0.09090909, 0.05330018,
#        0.09090909, 0.10660036, 0.06154575, 0.05504819, 0.04767313,
#        0.11009638, 0.05504819, 0.11826248, 0.10660036, 0.12856487,
#        0.10660036, 0.12309149, 0.11396058, 0.10341754, 0.10660036,
# ...

# %%
def recommend(medicine):
    medicine_index = new_df[new_df['Name_of_Medicine'] == medicine].index[0]
    distances = similarity[medicine_index]
    medicines_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    
    for i in medicines_list:
        print(new_df.iloc[i[0]].Name_of_Medicine)

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('medicine_dict.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
